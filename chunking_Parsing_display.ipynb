# %% [markdown]
# <a href="https://colab.research.google.com/github/Yousefalmutairi91/KDM_ICP2/blob/main/chunking_Parsing_display.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import nltk
from nltk import parse, pos_tag, word_tokenize, ne_chunk, WordNetLemmatizer, RegexpParser, ChunkParserI
from nltk.tokenize import sent_tokenize
from textblob import Word
from textblob import TextBlob
# !pip install -U textblob
# !python -m textblob.download_corpora
# Out:
# Requirement already up-to-date: textblob in /usr/local/lib/python3.6/dist-packages (0.15.3)
# Requirement already satisfied, skipping upgrade: nltk>=3.1 in /usr/local/lib/python3.6/dist-packages (from textblob) (3.2.5)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from nltk>=3.1->textblob) (1.15.0)
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# Finished.

# %%
text = "Xi Jinping is a Chinese politician who has served as General Secretary of the Chinese Communist Party (CCP) and Chairman of the Central Military Commission (CMC) since 2012, and President of the People's Republic of China (PRC) since 2013. He has been the paramount leader of China, the most prominent political leader in the country, since 2012. The son of Chinese Communist veteran Xi Zhongxun, he was exiled to rural Yanchuan County as a teenager following his father's purge during the Cultural Revolutionandlived in a cave in the village of Liangjiahe, where he joined the CCP and worked as the party secretary."

text_words = nltk.word_tokenize(text)
text_words
# Out:
# ['Xi',
#  'Jinping',
#  'is',
#  'a',
#  'Chinese',
#  'politician',
#  'who',
#  'has',
#  'served',
#  'as',
#  'General',
#  'Secretary',
#  'of',
#  'the',
#  'Chinese',
#  'Communist',
#  'Party',
#  '(',
#  'CCP',
#  ')',
#  'and',
#  'Chairman',
#  'of',
#  'the',
#  'Central',
#  'Military',
#  'Commission',
#  '(',
#  'CMC',
#  ')',
#  'since',
#  '2012',
#  ',',
#  'and',
#  'President',
#  'of',
#  'the',
#  'People',
#  "'s",
#  'Republic',
#  'of',
#  'China',
#  '(',
#  'PRC',
#  ')',
#  'since',
#  '2013',
#  '.',
#  'He',
#  'has',
#  'been',
#  'the',
#  'paramount',
#  'leader',
#  'of',
#  'China',
#  ',',
#  'the',
#  'most',
#  'prominent',
#  'political',
#  'leader',
#  'in',
#  'the',
#  'country',
#  ',',
#  'since',
#  '2012',
#  '.',
#  'The',
#  'son',
#  'of',
#  'Chinese',
#  'Communist',
#  'veteran',
#  'Xi',
#  'Zhongxun',
#  ',',
#  'he',
#  'was',
#  'exiled',
#  'to',
#  'rural',
#  'Yanchuan',
#  'County',
#  'as',
#  'a',
#  'teenager',
#  'following',
#  'his',
#  'father',
#  "'s",
#  'purge',
#  'during',
#  'the',
#  'Cultural',
#  'Revolutionandlived',
#  'in',
#  'a',
#  'cave',
#  'in',
#  'the',
#  'village',
#  'of',
#  'Liangjiahe',
#  ',',
#  'where',
#  'he',
#  'joined',
#  'the',
#  'CCP',
#  'and',
#  'worked',
#  'as',
#  'the',
#  'party',
#  'secretary',
#  '.']

# %%
#print POS tag

print(nltk.pos_tag(text_words))
# Out:
# [('Xi', 'NN'), ('Jinping', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('Chinese', 'JJ'), ('politician', 'NN'), ('who', 'WP'), ('has', 'VBZ'), ('served', 'VBN'), ('as', 'IN'), ('General', 'NNP'), ('Secretary', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Chinese', 'NNP'), ('Communist', 'NNP'), ('Party', 'NNP'), ('(', '('), ('CCP', 'NNP'), (')', ')'), ('and', 'CC'), ('Chairman', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Central', 'NNP'), ('Military', 'NNP'), ('Commission', 'NNP'), ('(', '('), ('CMC', 'NNP'), (')', ')'), ('since', 'IN'), ('2012', 'CD'), (',', ','), ('and', 'CC'), ('President', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('People', 'NNP'), ("'s", 'POS'), ('Republic', 'NNP'), ('of', 'IN'), ('China', 'NNP'), ('(', '('), ('PRC', 'NNP'), (')', ')'), ('since', 'IN'), ('2013', 'CD'), ('.', '.'), ('He', 'PRP'), ('has', 'VBZ'), ('been', 'VBN'), ('the', 'DT'), ('paramount', 'JJ'), ('leader', 'NN'), ('of', 'IN'), ('China', 'NNP'), (',', ','), ('the', 'DT'), ('most', 'RBS'), ('prominent', 'JJ'), ('political', 'JJ'), ('leader', 'NN'), ('in', 'IN'), ('the', 'DT'), ('country', 'NN'), (',', ','), ('since', 'IN'), ('2012', 'CD'), ('.', '.'), ('The', 'DT'), ('son', 'NN'), ('of', 'IN'), ('Chinese', 'JJ'), ('Communist', 'NNP'), ('veteran', 'NN'), ('Xi', 'NNP'), ('Zhongxun', 'NNP'), (',', ','), ('he', 'PRP'), ('was', 'VBD'), ('exiled', 'VBN'), ('to', 'TO'), ('rural', 'JJ'), ('Yanchuan', 'NNP'), ('County', 'NNP'), ('as', 'IN'), ('a', 'DT'), ('teenager', 'NN'), ('following', 'VBG'), ('his', 'PRP$'), ('father', 'NN'), ("'s", 'POS'), ('purge', 'NN'), ('during', 'IN'), ('the', 'DT'), ('Cultural', 'NNP'), ('Revolutionandlived', 'NNP'), ('in', 'IN'), ('a', 'DT'), ('cave', 'NN'), ('in', 'IN'), ('the', 'DT'), ('village', 'NN'), ('of', 'IN'), ('Liangjiahe', 'NNP'), (',', ','), ('where', 'WRB'), ('he', 'PRP'), ('joined', 'VBD'), ('the', 'DT'), ('CCP', 'NNP'), ('and', 'CC'), ('worked', 'VBD'), ('as', 'IN'), ('the', 'DT'), ('party', 'NN'), ('secretary', 'NN'), ('.', '.')]

# %%
grammer = "NP: {<DT>?<JJ>*<NN>}"
chunk_parser = nltk.RegexpParser(grammer)

# %%
nlp = spacy.load("en_core_web_sm")  # load the English model
doc = nlp(text)    # process a text and create a Doc object
for chunk in doc.noun_chunks:       # iterate over the noun chunks in the Doc
    print(chunk.text, chunk.label_, chunk.root.text)
# Out:
# Xi Jinping NP Jinping
# a Chinese politician NP politician
# who NP who
# the Chinese Communist Party NP Party
# Chairman NP Chairman
# the Central Military Commission NP Commission
# CMC NP CMC
# President NP President
# the People's Republic NP Republic
# China NP China
# (PRC NP PRC
# He NP He
# the paramount leader NP leader
# China NP China
# the most prominent political leader NP leader
# the country NP country
# Chinese Communist veteran Xi Zhongxun NP Zhongxun
# he NP he
# Yanchuan County NP County
# a teenager NP teenager
# his father's purge NP purge
# a cave NP cave
# the village NP village
# Liangjiahe NP Liangjiahe
# he NP he
# the CCP NP CCP
# the party secretary NP secretary

# %%
for token in doc:
  print("{0}/{1} <-- {2} <-- {3}/{4}".format(token.text, token.tag_, token.dep_, token.head.text, token.head.tag_))
# Out:
# Xi/NNP <-- compound <-- Jinping/NNP
# Jinping/NNP <-- nsubj <-- is/VBZ
# is/VBZ <-- ROOT <-- is/VBZ
# a/DT <-- det <-- politician/NN
# Chinese/JJ <-- amod <-- politician/NN
# politician/NN <-- attr <-- is/VBZ
# who/WP <-- nsubj <-- served/VBN
# has/VBZ <-- aux <-- served/VBN
# served/VBN <-- relcl <-- politician/NN
# as/IN <-- prep <-- served/VBN
# General/NNP <-- compound <-- Secretary/NNP
# Secretary/NNP <-- nmod <-- CCP/NNP
# of/IN <-- prep <-- Secretary/NNP
# the/DT <-- det <-- Party/NNP
# Chinese/NNP <-- compound <-- Party/NNP
# Communist/NNP <-- compound <-- Party/NNP
# Party/NNP <-- pobj <-- of/IN
# (/-LRB- <-- punct <-- CCP/NNP
# CCP/NNP <-- pobj <-- as/IN
# )/-RRB- <-- punct <-- CCP/NNP
# and/CC <-- cc <-- politician/NN
# Chairman/NNP <-- conj <-- politician/NN
# of/IN <-- prep <-- Chairman/NNP
# the/DT <-- det <-- Commission/NNP
# Central/NNP <-- compound <-- Commission/NNP
# Military/NNP <-- compound <-- Commission/NNP
# Commission/NNP <-- pobj <-- of/IN
# (/-LRB- <-- punct <-- Commission/NNP
# CMC/NNP <-- appos <-- Commission/NNP
# )/-RRB- <-- punct <-- is/VBZ
# since/IN <-- prep <-- is/VBZ
# 2012/CD <-- pobj <-- since/IN
# ,/, <-- punct <-- is/VBZ
# and/CC <-- cc <-- is/VBZ
# President/NNP <-- conj <-- is/VBZ
# of/IN <-- prep <-- President/NNP
# the/DT <-- det <-- People/NNPS
# People/NNPS <-- poss <-- Republic/NNP
# 's/POS <-- case <-- People/NNPS
# Republic/NNP <-- pobj <-- of/IN
# of/IN <-- prep <-- Republic/NNP
# China/NNP <-- pobj <-- of/IN
# (/-LRB- <-- punct <-- PRC/NNP
# PRC/NNP <-- appos <-- Republic/NNP
# )/-RRB- <-- punct <-- President/NNP
# since/IN <-- prep <-- is/VBZ
# 2013/CD <-- pobj <-- since/IN
# ./. <-- punct <-- is/VBZ
# He/PRP <-- nsubj <-- been/VBN
# has/VBZ <-- aux <-- been/VBN
# been/VBN <-- ROOT <-- been/VBN
# the/DT <-- det <-- leader/NN
# paramount/JJ <-- amod <-- leader/NN
# leader/NN <-- attr <-- been/VBN
# of/IN <-- prep <-- leader/NN
# China/NNP <-- pobj <-- of/IN
# ,/, <-- punct <-- leader/NN
# the/DT <-- det <-- leader/NN
# most/RBS <-- advmod <-- prominent/JJ
# prominent/JJ <-- amod <-- leader/NN
# political/JJ <-- amod <-- leader/NN
# leader/NN <-- appos <-- leader/NN
# in/IN <-- prep <-- leader/NN
# the/DT <-- det <-- country/NN
# country/NN <-- pobj <-- in/IN
# ,/, <-- punct <-- been/VBN
# since/IN <-- prep <-- been/VBN
# 2012/CD <-- pobj <-- since/IN
# ./. <-- punct <-- been/VBN
# The/DT <-- det <-- son/NN
# son/NN <-- dep <-- was/VBD
# of/IN <-- prep <-- son/NN
# Chinese/NNP <-- amod <-- veteran/NN
# Communist/JJ <-- amod <-- veteran/NN
# veteran/NN <-- compound <-- Zhongxun/NNP
# Xi/NNP <-- compound <-- Zhongxun/NNP
# Zhongxun/NNP <-- pobj <-- of/IN
# ,/, <-- punct <-- was/VBD
# he/PRP <-- nsubj <-- was/VBD
# was/VBD <-- ROOT <-- was/VBD
# exiled/VBN <-- acomp <-- was/VBD
# to/IN <-- aux <-- rural/JJ
# rural/JJ <-- advcl <-- was/VBD
# Yanchuan/NNP <-- compound <-- County/NNP
# County/NNP <-- dobj <-- rural/JJ
# as/IN <-- prep <-- rural/JJ
# a/DT <-- det <-- teenager/NN
# teenager/NN <-- pobj <-- as/IN
# following/VBG <-- acl <-- teenager/NN
# his/PRP$ <-- poss <-- father/NN
# father/NN <-- poss <-- purge/NN
# 's/POS <-- case <-- father/NN
# purge/NN <-- dobj <-- following/VBG
# during/IN <-- prep <-- purge/NN
# the/DT <-- det <-- Revolutionandlived/VBN
# Cultural/NNP <-- compound <-- Revolutionandlived/VBN
# Revolutionandlived/VBN <-- pobj <-- during/IN
# in/IN <-- prep <-- Revolutionandlived/VBN
# a/DT <-- det <-- cave/NN
# cave/NN <-- pobj <-- in/IN
# in/IN <-- prep <-- cave/NN
# the/DT <-- det <-- village/NN
# village/NN <-- pobj <-- in/IN
# of/IN <-- prep <-- village/NN
# Liangjiahe/NNP <-- pobj <-- of/IN
# ,/, <-- punct <-- Liangjiahe/NNP
# where/WRB <-- advmod <-- joined/VBD
# he/PRP <-- nsubj <-- joined/VBD
# joined/VBD <-- relcl <-- Liangjiahe/NNP
# the/DT <-- det <-- CCP/NNP
# CCP/NNP <-- dobj <-- joined/VBD
# and/CC <-- cc <-- joined/VBD
# worked/VBD <-- conj <-- joined/VBD
# as/IN <-- prep <-- worked/VBD
# the/DT <-- det <-- secretary/NN
# party/NN <-- compound <-- secretary/NN
# secretary/NN <-- pobj <-- as/IN
# ./. <-- punct <-- was/VBD

# %%
displacy.render(doc, style='dep', jupyter=True, options={'distance':80})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3a6ceea2f9bc4574bebe1f0f5901e424-0" class="displacy" width="8370" height="697.0" direction="ltr" style="max-width: none; height: 697.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Xi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">Jinping</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">Chinese</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">politician</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">who</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">served</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">General</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">Secretary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">Chinese</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Communist</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="1330">Party (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1330">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="1410">CCP)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="1570">Chairman</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1570">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">Central</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="1890">Military</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1890">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">Commission (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">CMC)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="2130">since</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2130">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">2012,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="2290">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2290">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="2370">President</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2370">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="607.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">of</tspan>
#     <tspan class="displacy-tag" dy="2em"

# %%
lemmatizer = WordNetLemmatizer()
punctuations="?:!.,;()"
for word in text_words:
    if word in punctuations:
        text_words.remove(word)
print("{0:20}{1:20}".format("Word", "Lemmatization"))
for word in text_words:
    print("{0:20}{1:20}".format(word, lemmatizer.lemmatize(word, pos="v")))
# Out:
# Word                Lemmatization
# Xi                  Xi
# Jinping             Jinping
# is                  be
# a                   a
# Chinese             Chinese
# politician          politician
# who                 who
# has                 have
# served              serve
# as                  as
# General             General
# Secretary           Secretary
# of                  of
# the                 the
# Chinese             Chinese
# Communist           Communist
# Party               Party
# CCP                 CCP
# and                 and
# Chairman            Chairman
# of                  of
# the                 the
# Central             Central
# Military            Military
# Commission          Commission
# CMC                 CMC
# since               since
# 2012                2012
# and                 and
# President           President
# of                  of
# the                 the
# People              People
# 's                  's
# Republic            Republic
# of                  of
# China               China
# PRC                 PRC
# since               since
# 2013                2013
# He                  He
# has                 have
# been                be
# the                 the
# paramount           paramount
# leader              leader
# of                  of
# China               China
# the                 the
# most                most
# prominent           prominent
# political           political
# leader              leader
# in                  in
# the                 the
# country             country
# since               since
# 2012                2012
# The                 The
# son                 son
# of                  of
# Chinese             Chinese
# Communist           Communist
# veteran             veteran
# Xi                  Xi
# Zhongxun            Zhongxun
# he                  he
# was                 be
# exiled              exile
# to                  to
# rural               rural
# Yanchuan            Yanchuan
# County              County
# as                  as
# a                   a
# teenager            teenager
# following           follow
# his                 his
# father              father
# 's                  's
# purge               purge
# during              during
# the                 the
# Cultural            Cultural
# Revolutionandlived  Revolutionandlived
# in                  in
# a                   a
# cave                cave
# in                  in
# the                 the
# village             village
# of                  of
# Liangjiahe          Liangjiahe
# where               where
# he                  he
# joined              join
# the                 the
# CCP                 CCP
# and                 and
# worked              work
# as                  as
# the                 the
# party               party
# secretary           secretary

# %%
ner = nlp(text)
print([(y.text, y.label_) for y in ner.ents])
# Out:
# [('Xi Jinping', 'PERSON'), ('Chinese', 'NORP'), ('the Chinese Communist Party', 'ORG'), ('CCP', 'ORG'), ('the Central Military Commission', 'ORG'), ('2012', 'DATE'), ("the People's Republic of China", 'GPE'), ('PRC', 'GPE'), ('2013', 'DATE'), ('China', 'GPE'), ('2012', 'DATE'), ('Chinese', 'NORP'), ('Communist', 'NORP'), ('Xi Zhongxun', 'PERSON'), ('Yanchuan County', 'GPE'), ('the Cultural Revolutionandlived', 'EVENT'), ('Liangjiahe', 'GPE'), ('CCP', 'ORG')]

# %%
# !python -m spacy download en
import spacy
nlp = spacy.load('en')
# Out:
# Requirement already satisfied: en_core_web_sm==2.2.5 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz#egg=en_core_web_sm==2.2.5 in /usr/local/lib/python3.6/dist-packages (2.2.5)
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.6/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.8.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.19.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (53.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.41.1)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2020.12.5)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.4.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
# Out:
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.
